# %%
dbfs_location = "abfss://demo@michaelformula1dl.dfs.core.windows.net"
demo_location = "abfss://demo@michaelformula1dl.dfs.core.windows.net/circuits.csv"

raw_folder_path = "abfss://raw@michaelformula1dl.dfs.core.windows.net"
processed_folder_path = "abfss://processed@michaelformula1dl.dfs.core.windows.net"
presentation_folder_path = "abfss://presentation@michaelformula1dl.dfs.core.windows.net"
