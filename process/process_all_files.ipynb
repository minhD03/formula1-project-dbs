# %% [markdown]
# # Formula 1 Process All Files

# %%
# %run ../common/configuration

# %%
# %run ../common/functions

# %% [markdown]
# ## 1) Process Circuits file:

# %%
dbutils.notebook.run(
    "process_circuits",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/circuits/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/dim_circuits/delta"))

# %% [markdown]
# ## 2) Process Constructors file:

# %%
dbutils.notebook.run(
    "process_constructors",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/constructors/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/dim_constructors/delta"))

# %% [markdown]
# ## 3) Process Drivers File:

# %%
dbutils.notebook.run(
    "process_drivers",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/drivers/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/dim_drivers/delta"))

# %% [markdown]
# ## 4) Process Constructor Standings File:

# %%
dbutils.notebook.run(
    "process_constructor_standings",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/constructor_standings/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_constructor_standings/delta"))

# %% [markdown]
# ## 5) Process Driver Standings File:

# %%
dbutils.notebook.run(
    "process_driver_standings",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/driver_standings/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_driver_standings/delta"))

# %% [markdown]
# ## 6) Process Lap Times file:

# %%
dbutils.notebook.run(
    "process_lap_times",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/lap_times/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_lap_times/delta"))

# %% [markdown]
# ## 7) Process Pit Stops File:

# %%
dbutils.notebook.run(
    "process_pit_stops",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/pit_stops/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_pit_stops/delta"))

# %% [markdown]
# ## 8) Process Qualifying File:

# %%
dbutils.notebook.run(
    "process_qualifying",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/qualifying/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_qualifying/delta"))

# %% [markdown]
# ## 9) Process Races File:

# %%
dbutils.notebook.run(
    "process_races",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/races/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_races/delta"))

# %% [markdown]
# ## 10) Process Results File:

# %%
dbutils.notebook.run(
    "process_results",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/results/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_results/delta"))

# %% [markdown]
# ## 11) Process Sprint

# %%
dbutils.notebook.run(
    "process_sprint",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/sprint/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_sprint/delta"))

# %% [markdown]
# ## 12) Process Status File:

# %%
dbutils.notebook.run(
    "process_status",
    600,
)

display(spark.read.format("delta").load(f"{processed_folder_path}/status/delta"))
display(spark.read.format("delta").load(f"{presentation_folder_path}/fact_status/delta"))
